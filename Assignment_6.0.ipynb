# %% [markdown]
# Q1. Write a Python program that prints the multiplication table for a given number (between 1 and 10) using a for loop.
#
# Hint:
#
# Ask the user for a number between 1 and 10 . Use a for loop to iterate through the numbers from 1 to 10. For each iteration, calculate the product of the given number and the current number in the loop. Print the result in a readable format (e.g., 5 x 1 = 5).

# %%
userinp = int(input("please enter a number"))
for i in range (1,11):
  print(f"{userinp} x {i} = {userinp*i}")
# Out:
# please enter a number8
# 8 x 1 = 8
# 8 x 2 = 16
# 8 x 3 = 24
# 8 x 4 = 32
# 8 x 5 = 40
# 8 x 6 = 48
# 8 x 7 = 56
# 8 x 8 = 64
# 8 x 9 = 72
# 8 x 10 = 80

# %% [markdown]
# Q2. Stop sending emails after 3 users (Using for loop and break)
#
# users = ["Ali", "Sara", "John", "Zara", "Mike"]
#
# Output:
#
# Email sent to Ali
#
# Email sent to Sara
#
# Email sent to John
#
# Limit reached. Stop sending emails.

# %%
users = ["Ali", "Sara", "John", "Zara", "Mike"]

# %%
for email in users:
  if email == users[3]:
    break
  else:
    print(f"Email sent to {email}")
# Out:
# Email sent to Ali
# Email sent to Sara
# Email sent to John

# %%
users = ["Ali", "Sara", "John", "Zara", "Mike"]

count = 0
for email in users:
  print(f"Email sent to {email}")
  count += 1
  if count == 3:
  #else:
      print("Limit reached. Stop sending emails.")
      break
# Out:
# Email sent to Ali
# Email sent to Sara
# Email sent to John
# Limit reached. Stop sending emails.

# %% [markdown]
# Q3. Stop monitoring temperature if critical temperature reached (Using for loop and break)
#
# temps = [22, 25, 30, 45, 28] critical = 40
#
# Ouput:
#
# Temperature: 22
#
# Temperature: 25
#
# Temperature: 30
#
# Critical temperature reached! Stop monitoring.

# %%
temps = [22, 25, 30, 42, 28,45]

# %%
for temperature in temps:
  print(temperature)
  if temperature >= 39:
    print("Critical temperature reached! Stop monitoring.")
    #print(temperature)
    break
# Out:
# 22
# 25
# 30
# 40
# Critical temperature reached! Stop monitoring.

# %% [markdown]
# Q4. Calculate total price of items in a shopping cart (Using For loop)
#
# cart = [100, 250, 50, 300]
#
# Output:
#
# Total Price: 700

# %%
cart = [100, 250, 50, 300]

# %%
sums = 0
for carts in cart:
   sums += carts
print(sums)
# Out:
# 700

# %% [markdown]
# Q5. Skip customers with unpaid bills (Using For loop and continue)
#
# customers = [ {"name": "Ali", "paid": True},
#
# {"name": "Sara", "paid": False},
#
# {"name": "John", "paid": True}
# ]
#
# Output:
#
# Access granted to: Ali
#
# Access granted to: John

# %%
customers = [ {"name": "Ali", "paid": True},

{"name": "Sara", "paid": False},

{"name": "John", "paid": True} ]

# %%
for customer in customers:
   if customer['paid'] == False:
      continue
   print(f"Access granted to: {customer}")
# Out:
# Access granted to: {'name': 'Ali', 'paid': True}
# Access granted to: {'name': 'John', 'paid': True}

# %% [markdown]
# Q6. Send personalized emails to a list of users (Using for loop)
#
# users = ["Ali", "Sara", "John"]
#
# Output:
#
# Hello Ali, your subscription is active!
# Hello Sara, your subscription is active!
# Hello John, your subscription is active!

# %%
users = ["Ali", "Sara", "John"]

for user in users:
 print(f"Hello {user}, your subscription is active!")
# Out:
# Hello Ali, your subscription is active!
# Hello Sara, your subscription is active!
# Hello John, your subscription is active!

# %% [markdown]
# Q7. Extract domain names from email list (Using for loop)
#
# emails = ["ali@gmail.com", "sara@yahoo.com", "john@hotmail.com"]
#
# Output:
#
# domains: ['gmail.com', 'yahoo.com', 'hotmail.com']

# %%
emails = ["ali@gmail.com", "sara@yahoo.com", "john@hotmail.com"]

# %%
for email in emails:
  if "@" in email:
      print(email.split("@")[1])
# Out:
# gmail.com
# yahoo.com
# hotmail.com

# %% [markdown]
# Q8. Print only overdue tasks (Using for loop)
#
# tasks = [ {"task": "Pay bills", "status": "done"},
#
# {"task": "Submit report", "status": "pending"},
#
# {"task": "Clean house", "status": "pending"}
# ]
#
# Ouput:
#
# Overdue: Submit report
#
# Overdue: Clean house

# %%
tasks = [ {"task": "Pay bills", "status": "done"},

{"task": "Submit report", "status": "pending"},

{"task": "Clean house", "status": "pending"} ]

# %%
for overdue in tasks:
   if overdue["status"] == "done":
      continue
   print(f"Overdue: {overdue["task"]}")
# Out:
# Overdue: Submit report
# Overdue: Clean house

# %% [markdown]
# Q9. Extract names of employees with salary above 50,000
#
# employees = [ {"name": "Ali", "salary": 60000},
#
# {"name": "Sara", "salary": 45000},
#
# {"name": "John", "salary": 70000}
# ]
#
# Output:
#
# Ali earns above 50,000
#
# John earns above 50,000

# %%
employees = [ {"name": "Ali", "salary": 60000},

{"name": "Sara", "salary": 45000},

{"name": "John", "salary": 70000} ]

# %%
for emp in employees:
    if emp["salary"] > 50000:
        print(f"{emp['name']} earns above 50,000")
# Out:
# Ali earns above 50,000
# John earns above 50,000

# %% [markdown]
# Q10. Skip weekends while printing workdays (Using for loop and continue)
#
# days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
#
# Output:
#
# Workday: Monday
#
# Workday: Tuesday
#
# Workday: Wednesday
#
# Workday: Thursday
#
# Workday: Friday

# %%
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]

# %%
for weekend in days:
    if weekend == "Saturday" or weekend == "Sunday":
       continue
    print(f"Workday:{weekend}")
# Out:
# Workday:Monday
# Workday:Tuesday
# Workday:Wednesday
# Workday:Thursday
# Workday:Friday
